# %% [markdown]
# Weights In PyTorch Model

# %%
# Importing the libraries
import torch
import torch.nn as nn

# %%
model_new = torch.load('/home/h6x/git_projects/ornl-overdose-modeling-per-images/SEResNet_15_channels/models/se_restnet.pth')

# %%
model_new['model_state_dict']
# Out:
# OrderedDict([('blocks.0.p.c.weight',
#               tensor([[[[ 0.1508]],
#
#                        [[ 0.0750]],
#
#                        [[-0.0324]],
#
#                        ...,
#
#                        [[ 0.0696]],
#
#                        [[-0.0817]],
#
#                        [[ 0.2859]]],
#
#
#                       [[[-0.2418]],
#
#                        [[-0.0093]],
#
#                        [[-0.3322]],
#
#                        ...,
#
#                        [[-0.2525]],
#
#                        [[-0.0492]],
#
#                        [[-0.0542]]],
#
#
#                       [[[-0.4757]],
#
#                        [[-0.1442]],
#
#                        [[ 0.0926]],
#
#                        ...,
#
#                        [[ 0.2602]],
#
#                        [[ 0.0532]],
#
#                        [[ 0.0239]]],
#
#
#                       ...,
#
#
#                       [[[ 0.1123]],
#
#                        [[ 0.0088]],
#
# ...

# %%
type(model_new['model_state_dict'])
# Out:
# collections.OrderedDict

# %%
# get the keys
model_new['model_state_dict'].keys()
# Out:
# odict_keys(['blocks.0.p.c.weight', 'blocks.0.p.bn.weight', 'blocks.0.p.bn.bias', 'blocks.0.p.bn.running_mean', 'blocks.0.p.bn.running_var', 'blocks.0.p.bn.num_batches_tracked', 'blocks.0.c1.c.weight', 'blocks.0.c1.bn.weight', 'blocks.0.c1.bn.bias', 'blocks.0.c1.bn.running_mean', 'blocks.0.c1.bn.running_var', 'blocks.0.c1.bn.num_batches_tracked', 'blocks.0.c2.c.weight', 'blocks.0.c2.bn.weight', 'blocks.0.c2.bn.bias', 'blocks.0.c2.bn.running_mean', 'blocks.0.c2.bn.running_var', 'blocks.0.c2.bn.num_batches_tracked', 'blocks.0.c3.c.weight', 'blocks.0.c3.bn.weight', 'blocks.0.c3.bn.bias', 'blocks.0.c3.bn.running_mean', 'blocks.0.c3.bn.running_var', 'blocks.0.c3.bn.num_batches_tracked', 'blocks.0.seblock.fc1.weight', 'blocks.0.seblock.fc2.weight', 'blocks.1.c1.c.weight', 'blocks.1.c1.bn.weight', 'blocks.1.c1.bn.bias', 'blocks.1.c1.bn.running_mean', 'blocks.1.c1.bn.running_var', 'blocks.1.c1.bn.num_batches_tracked', 'blocks.1.c2.c.weight', 'blocks.1.c2.bn.weight', 'blocks.1.c2.bn.bias', 'bl
# ...

# %%
import pandas as pd

# empty dataframe
df = pd.DataFrame()

# %%
# for each key, print the values
for key in model_new['model_state_dict']:
    print(key)
    # print(model_new['model_state_dict'][key])
    # if key contains 'seblock' print the values
    if 'seblock' in key:
        print(model_new['model_state_dict'][key])

        print(model_new['model_state_dict'][key].shape)
# Out:
# blocks.0.p.c.weight
# blocks.0.p.bn.weight
# blocks.0.p.bn.bias
# blocks.0.p.bn.running_mean
# blocks.0.p.bn.running_var
# blocks.0.p.bn.num_batches_tracked
# blocks.0.c1.c.weight
# blocks.0.c1.bn.weight
# blocks.0.c1.bn.bias
# blocks.0.c1.bn.running_mean
# blocks.0.c1.bn.running_var
# blocks.0.c1.bn.num_batches_tracked
# blocks.0.c2.c.weight
# blocks.0.c2.bn.weight
# blocks.0.c2.bn.bias
# blocks.0.c2.bn.running_mean
# blocks.0.c2.bn.running_var
# blocks.0.c2.bn.num_batches_tracked
# blocks.0.c3.c.weight
# blocks.0.c3.bn.weight
# blocks.0.c3.bn.bias
# blocks.0.c3.bn.running_mean
# blocks.0.c3.bn.running_var
# blocks.0.c3.bn.num_batches_tracked
# blocks.0.seblock.fc1.weight
# tensor([[-0.0987, -0.0332, -0.0274,  ..., -0.0123, -0.0076,  0.0068],
#         [ 0.0661, -0.0664,  0.0921,  ..., -0.0750, -0.1277, -0.0501],
#         [-0.1029,  0.0218,  0.1260,  ..., -0.0596, -0.0395,  0.0779],
#         ...,
#         [-0.0362,  0.0393, -0.0963,  ..., -0.0048,  0.1254,  0.1531],
# ...
